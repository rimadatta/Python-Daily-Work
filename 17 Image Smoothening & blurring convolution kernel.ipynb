# %% [markdown]
# ##### Averaging Kernel

# %%
import cv2
import numpy as np

# Load an image
image = cv2.imread("images/lenna.png")

# Define a 3x3 "averaging" Kernel
kernel = np.ones((3,3), np.float32)/9

# Apply the kernel to smooth the image
smoothed_image= cv2.filter2D(image, -1, kernel)

# Show the original and smoothed images
cv2.imshow("original Image", image)
cv2.imshow("Smoothened Image", smoothed_image)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %% [markdown]
# ##### Gaussian Kernel

# %%
import matplotlib.pyplot as plt
import cv2
gray = cv2.imread("images/lena.png",0)
kernel_size = 5 # Any size can be taken. This will generate a column matrix of 5. Averaging Kernel has square matrix
kernel = cv2.getGaussianKernel(kernel_size, 1.25) # Generate Gaussian Kernel with higher value in the middle and lower value towards the edges. 1.25 is a sigma value and can be adjusted.
blurred = cv2.filter2D(gray, -1, kernel)
plt.figure(figsize=(16,9))
plt.subplot(1,2,1)
plt.title("Original Image")
plt.imshow(gray, cmap='gray')
plt.subplot(1,2,2)
plt.title("Blurred Image")
plt.imshow(blurred, cmap='gray')
