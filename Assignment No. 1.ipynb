# %%
import cv2
import matplotlib.pyplot as plt

#Load the image
image=cv2.imread("images/sachin.jpg",0)
cv2.imshow('First Image',image)
cv2.waitKey(0)
cv2.destroyAllWindows()
image1 =cv2.cvtColor(image,cv2.COLOR_BGR2RGB)
image.shape
# Out:
# (1075, 850)

# %%
image.size
# Out:
# 2741250

# %%
#Slicing img_plt
r=image1[:,:,0]
g=image1[:,:,1]
b=image1[:,:,2]
plt.subplot(1,3,1) # function to plot 3 simultaneous plots
plt.imshow(r,cmap='Reds')
plt.subplot(1,3,2)
plt.imshow(g,cmap='Greens')
plt.subplot(1,3,3)
plt.imshow(b,cmap='Blues')

# %%
plt.title("Sachin.jpg")
plt.imshow(image1)

# %%
plt.figure(figsize=(16,9))
plt.subplot(2,4,1)
plt.title('Coolwarm')
plt.imshow(image, cmap='coolwarm')
plt.subplot(2,4,2)
plt.title('Rainbow')
plt.imshow(image, cmap='rainbow')
plt.subplot(2,4,3)
plt.title('Tab10')
plt.imshow(image1, cmap='tab10')
plt.subplot(2,4,4)
plt.title('Seismic')
plt.imshow(image1, cmap='seismic')
plt.subplot(2,4,5)
plt.title('twilight')
plt.imshow(image1, cmap='twilight')
plt.subplot(2,4,6)
plt.title('turbo')
plt.imshow(image1, cmap='turbo')
plt.subplot(2,4,7)
plt.title('BuGn')
plt.imshow(image1, cmap='BuGn')

# %%
img_plt=plt.imread("images/lena.png")
img_plt[100:150,200:350] = 1
plt.imshow(img_plt)

# %%
vid=cv2.VideoCapture("images/nature.mp4")

# %%
#Metadata
width=int(vid.get(cv2.CAP_PROP_FRAME_WIDTH))
height=int(vid.get(cv2.CAP_PROP_FRAME_HEIGHT))
frames=int(vid.get(cv2.CAP_PROP_FRAME_COUNT))
fps=int(vid.get(cv2.CAP_PROP_FPS))

# %%
print("Video Resolution: ",height,width)
print("Total frames: ",frames)
print("FPS:",fps)
# Out:
# Video Resolution:  720 1270
# Total frames:  1409
# FPS: 26

# %%
#play video by extracting frames from video robots
while True:
    ret, frame=vid.read()
    if not ret:
        break
    #Process the frame (e.g., apply filters, detect objects)
    cv2.imshow("Video",frame)
    if cv2.waitKey(15)==ord('q'):
        break
cv2.destroyAllWindows()

# %%
timestamp='00:00:50'
timestamp.split(':')
# Out:
# ['00', '00', '50']

# %%
# get frame at a speific timestamp by separating hours, minutes and seconds
hours,minutes,seconds=[float(i) for i in timestamp.split(':')]
print(hours,minutes,seconds)
# Out:
# 0.0 0.0 50.0

# %%
trigger_frame = hours*3600*fps + minutes*60*fps + seconds*fps

# %%
vid.set(1,trigger_frame) #This will return only 1st frame of the time stamp
success,frame=vid.read()
#Save the frame into an image file in the current working directory
if success:
    cv2.imwrite('screen50.jpg',frame)
